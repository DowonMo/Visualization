# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import platform
import seaborn as sns

# 운영 체제 확인
if platform.system() == 'Darwin':  # Mac
    print('apple gothic')
    font_name = 'AppleGothic'
elif platform.system() == 'Windows':  # Windows
    font_name = 'NanumGothic'
else:
    font_name = None

# 한글 폰트 설정
if font_name:
    plt.rcParams['font.family'] = font_name

# 마이너스 부호 설정
plt.rcParams['axes.unicode_minus'] = False

# Future Warning 메시지 제거
import warnings
warnings.simplefilter(action = 'ignore', category = FutureWarning)
# Out:
# apple gothic

# %%
df = pd.read_csv('../data/tips.csv', index_col = 0)
df.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.figure()
sns.scatterplot(data = df,
                x = 'total_bill',
                y = 'tip')
ax = sns.rugplot(data = df,
            x = 'total_bill',
            y = 'tip')
ax.set_title('산점도와 Rug Plot')
ax.set_xlabel('총 지급액')
ax.set_ylabel('팁(tip)')
# Out:
# Text(0, 0.5, '팁(tip)')

# %%
plt.figure()
ax = sns.histplot(data = df,
             x = 'total_bill',
             kde = True,
             bins = 30)
ax.set_title('총 지급액 히스토그램')
ax.set_xlabel('총 지급액')
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
df['day'].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
# day 컬럼 영문 -> 한문 변경

def reset_label(x):
    if x == 'Sun':
        return '일요일'
    elif x == 'Sat':
        return '토요일'
    elif x == 'Thur':
        return '목요일'
    else:
        return '금요일'
    
df['day'] = df['day'].apply(lambda x: reset_label(x))

# %%
plt.figure()
ax = sns.barplot(data = df,
            x = 'day',
            y = 'tip',
            errwidth = 0,
            hue = 'time')
ax.set_title('요일에 따른 팁(tip')
ax.set_xlabel('요일')
ax.set_ylabel('팁(tip)')
# Out:
# Text(0, 0.5, '팁(tip)')

# %%
plt.figure()
ax = sns.boxplot(data = df,
            x = 'day',
            y = 'tip',
            hue = 'time')
ax.set_title('요일에 따른 팁(tip, boxplot)')
ax.set_xlabel('요일')
ax.set_ylabel('팁(tip)')
# Out:
# Text(0, 0.5, '팁(tip)')

# %%
plt.figure()
ax = sns.violinplot(data = df,
               x = 'day',
               y = 'tip',
               hue = 'time')
ax.set_title('요일에 따른 팁(tip, violinplot)')
ax.set_xlabel('요일')
ax.set_ylabel('팁(tip)')
# Out:
# Text(0, 0.5, '팁(tip)')

# %%
plt.figure()
ax = sns.stripplot(data = df,
                   x = 'day',
                   y = 'tip',
                   hue = 'time',
                   size = 3)
ax.set_title('요일에 따른 팁(tip, stripplot)')
ax.set_xlabel('요일')
ax.set_ylabel('팁(tip)')
# Out:
# Text(0, 0.5, '팁(tip)')

# %%
plt.figure()
ax = sns.swarmplot(data = df,
                   x = 'day',
                   y = 'tip',
                   hue = 'time')
ax.set_title('요일에 따른 팁(tip, swarmplot)')
ax.set_xlabel('요일')
ax.set_ylabel('팁(tip)')
# Out:
# Text(45.722222222222214, 0.5, '팁(tip)')

# %%
plt.figure()
sns.boxplot(data = df,
                 x = 'total_bill',
                 y = 'day',
                 palette = 'deep')
ax = sns.stripplot(data = df,
                   x = 'total_bill',
                   y = 'day',
                   color = '0.4')
ax.set_title('boxplot과 stripplot 동시 표현')
ax.set_xlabel('총 지급액')
ax.set_ylabel('요일')
# Out:
# Text(0, 0.5, '요일')
